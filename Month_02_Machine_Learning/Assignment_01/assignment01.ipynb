# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('titanic_data_updated.csv')

# %%
df.sample(20)
# Out:
#      PassengerId Survived  Pclass  \
# 114          115       no   third
# 89            90       no   third
# 612          613      yes   third
# 124          125       no   first
# 470          471       no   third
# 779          780      yes   first
# 391          392      yes   third
# 39            40      yes   third
# 207          208      yes   third
# 310          311      yes   first
# 857          858      yes   first
# 770          771       no   third
# 119          120       no   third
# 150          151       no  second
# 696          697       no   third
# 642          643       no   third
# 235          236       no   third
# 582          583       no  second
# 306          307      yes   first
# 862          863      yes   first
#
#                                                   Name     Sex   Age  SibSp  \
# 114                              Attalah, Miss. Malake  female  17.0      0
# 89                              Celotti, Mr. Francesco    male  24.0      0
# 612                        Murphy, Miss. Margaret Jane  female   NaN      1
# 124                        White, Mr. Percival Wayland    male  54.0      0
# 470                                  Keefe, Mr. Arthur    male   NaN      0
# 779  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...  female  43.0      0
# 391                             Jansson, Mr. Carl Olof    male  21.0      0
# 39                         Nicola-Yarred, Miss. Jamila  female  14.0      1
# 207                        Albimona, Mr. Nassef Cassem    male  26.0      0
# 310                     Hays, Miss. Margaret Bechstein  female  24.0      0
# 857                             Daly, Mr. Peter Denis     male  51.0      0
# 770                             Lievens, Mr. Rene Aime    male  24.0      0
# 119                  Andersson, Miss. Ellis Anna Maria  female   2.0      4
# 150                         Bateman, Rev. Robert James    male  51.0      0
# 696                                   Kelly, Mr. James    male  44.0      0
# 642                      Skoog, Miss. Margit Elizabeth  female   2.0      3
# 235                       Harknett, Miss. Alice Phoebe  female   NaN      0
# 582                         Downton, Mr. William James    male  54.0      0
# 306                            Fleming, Miss. Margaret  female   NaN      0
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
#
#      Parch       Ticket      Fare Cabin Embarked
# 114      0         2627   14.4583   NaN        C
# 89       0       343275    8.0500   NaN        S
# 612      0       367230   15.5000   NaN        Q
# 124      1        35281   77.2875   D26        S
# 470      0       323592    7.2500   NaN        S
# 779      1        24160  211.3375    B3        S
# 391      0       350034    7.7958   NaN        S
# 39       0         2651   11.2417   NaN        C
# 207      0         2699   18.7875   NaN        C
# 310      0        11767   83.1583   C54        C
# 857      0       113055   26.5500   E17        S
# 770      0       345781    9.5000   NaN        S
# 119      2       347082   31.2750   NaN        S
# 150      0  S.O.P. 1166   12.5250   NaN        S
# 696      0       363592    8.0500   NaN        S
# 642      2       347088   27.9000   NaN        S
# 235      0   W./C. 6609    7.5500   NaN        S
# 582      0        28403   26.0000   NaN        S
# 306      0        17421  110.8833   NaN        C
# 862      0        17466   25.9292   D17        S

# %% [markdown]
# Question 1
#
# Load the Titanic dataset and display:
#
# Dataset shape
#
# First 10 rows
#
# 5 random samples

# %%
df.shape

print(f"Total potential features :{df.shape[1]}")
print(f"Total sample data :{df.shape[0]}")
# Out:
# Total potential features :12
# Total sample data :891

# %%
df.head(10)
# Out:
#    PassengerId Survived  Pclass  \
# 0            1       no   third
# 1            2      yes   first
# 2            3      yes   third
# 3            4      yes   first
# 4            5       no   third
# 5            6       no   third
# 6            7       no   first
# 7            8       no   third
# 8            9      yes   third
# 9           10      yes  second
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
df.sample(5)
# Out:
#      PassengerId Survived  Pclass                            Name   Sex  \
# 365          366       no   third  Adahl, Mr. Mauritz Nils Martin  male
# 640          641       no   third          Jensen, Mr. Hans Peder  male
# 639          640       no   third      Thorneycroft, Mr. Percival  male
# 606          607       no   third               Karaic, Mr. Milan  male
# 755          756      yes  second       Hamalainen, Master. Viljo  male
#
#        Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 365  30.00      0      0  C 7076   7.2500   NaN        S
# 640  20.00      0      0  350050   7.8542   NaN        S
# 639    NaN      1      0  376564  16.1000   NaN        S
# 606  30.00      0      0  349246   7.8958   NaN        S
# 755   0.67      1      1  250649  14.5000   NaN        S

# %% [markdown]
# Question 2
#
# Perform feature screening on the Titanic dataset by:
#
# Finding total missing values
#
# Finding duplicate rows
#
# Removing duplicate rows permanently

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print("Duplicate Rows: ")
print(df.duplicated().sum())

df.drop_duplicates(inplace=True)
# Out:
# Duplicate Rows:
# 0

# %% [markdown]
# Question 3
#
# Perform statistical profiling of the Titanic dataset and display:
#
# Dataset information
#
# Statistical summary of numerical columns
#
# Also write 2 observations from the output.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    object
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId         Age       SibSp       Parch        Fare
# count   891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.699118    0.523008    0.381594   32.204208
# std     257.353842   14.526497    1.102743    0.806057   49.693429
# min       1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000   38.000000    1.000000    0.000000   31.000000
# max     891.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# #### I can see the dataset column with data type that will help me to decide feature and target column.
# #### I can also see statistics of 5 numercial columns

# %% [markdown]
# Question 4
#
# Perform univariate categorical analysis on the Survived column by:
#
# Creating a countplot
#
# Calculating percentage distribution
#
# Creating a pie chart
#
# Write 2 insights from the analysis.

# %%
sns.countplot(data = df , x=df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
(df['Survived'].value_counts() / len(df) ) * 100
# Out:
# Survived
# no     61.616162
# yes    38.383838
# Name: count, dtype: float64

# %%
survived_count =  df['Survived'].value_counts()

survived_label = df['Survived'].unique()

plt.pie(survived_count, labels = survived_label, autopct="%1.1f")
plt.title('Pie chart of survival rate')
plt.show()

# %% [markdown]
# ### 2 Observation:
# #### In countplot I can see approximate number of how many people survived or not.
# #### Also the piechart helps to visualize with percentage of survived and not survived data.

# %% [markdown]
# Question 5
#
# Perform univariate numerical analysis on the Age column by:
#
# Creating a histogram
#
# Creating a KDE plot
#
# Write 2 observations from the plots.

# %%
sns.histplot(df['Age'],bins=50)

plt.title('Histogram of Age')
plt.xlabel('Ages')
plt.ylabel('Frequency')

plt.show()

# %%
sns.kdeplot(df['Age'])
plt.title('KDE plot of Age')
plt.xlabel('Ages')
plt.ylabel('Probabilty Distribution')

plt.show()

# %% [markdown]
# ### 2 Observation:
# #### In histogram we can see frequency of each age group to determine the peak age group.
# #### KDE plot gives continous value for ages to accurately determine peak value.

# %% [markdown]
# Question 6
#
# Perform multivariate analysis between Sex and Survived using a countplot with hue.
#
# Also calculate normalized survival ratios using groupby().
#
# Write 2 insights from the analysis.

# %%
sns.countplot(x=df['Sex'], hue=df['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
ratio= df.groupby('Sex')['Survived'].value_counts(normalize=True)

print(ratio)
# Out:
# Sex     Survived
# female  yes         0.742038
#         no          0.257962
# male    no          0.811092
#         yes         0.188908
# Name: proportion, dtype: float64

# %% [markdown]
# ### 2 Observation:
# #### We can see how many male or female survived in the plot.
# #### In ratio we can determine if the value will be biased or not for one group.

# %% [markdown]
# Question 7
#
# Create a barplot showing the relationship between Pclass and Fare.
#
# Write 2 observations from the visualization.

# %%
sns.barplot(x=df['Pclass'], y=df['Fare'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# ### 2 Observation:
# #### We can see Fare for each class in plot
# #### Value will be biased for first class as it is more

# %% [markdown]
# Question 8
#
# Create a KDE plot to compare the Age distribution of survived and non-survived passengers.
#
# Write 2 insights from the graph.

# %%
sns.kdeplot(data=df, x='Age', hue='Survived')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# Question 9
#
# Perform feature engineering and train-test split by:
#
# Dropping PassengerId, Name, and Ticket columns
#
# Separating features (X) and target (y)
#
# Splitting the dataset using test_size=0.2 and random_state=42
#
# Display the shapes of train and test datasets.

# %%
df.drop(['PassengerId', 'Name', 'Ticket'], axis=1, inplace=True)

# %%
df
# Out:
#     Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         no   third    male  22.0      1      0   7.2500   NaN        S
# 1        yes   first  female  38.0      1      0  71.2833   C85        C
# 2        yes   third  female  26.0      0      0   7.9250   NaN        S
# 3        yes   first  female  35.0      1      0  53.1000  C123        S
# 4         no   third    male  35.0      0      0   8.0500   NaN        S
# ..       ...     ...     ...   ...    ...    ...      ...   ...      ...
# 886       no  second    male  27.0      0      0  13.0000   NaN        S
# 887      yes   first  female  19.0      0      0  30.0000   B42        S
# 888       no   third  female   NaN      1      2  23.4500   NaN        S
# 889      yes   first    male  26.0      0      0  30.0000  C148        C
# 890       no   third    male  32.0      0      0   7.7500   NaN        Q
#
# [891 rows x 9 columns]

# %%
X= df.drop('Survived', axis=1)
X
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0     third    male  22.0      1      0   7.2500   NaN        S
# 1     first  female  38.0      1      0  71.2833   C85        C
# 2     third  female  26.0      0      0   7.9250   NaN        S
# 3     first  female  35.0      1      0  53.1000  C123        S
# 4     third    male  35.0      0      0   8.0500   NaN        S
# ..      ...     ...   ...    ...    ...      ...   ...      ...
# 886  second    male  27.0      0      0  13.0000   NaN        S
# 887   first  female  19.0      0      0  30.0000   B42        S
# 888   third  female   NaN      1      2  23.4500   NaN        S
# 889   first    male  26.0      0      0  30.0000  C148        C
# 890   third    male  32.0      0      0   7.7500   NaN        Q
#
# [891 rows x 8 columns]

# %%
Y= df['Survived']

Y
# Out:
# 0       no
# 1      yes
# 2      yes
# 3      yes
# 4       no
#       ...
# 886     no
# 887    yes
# 888     no
# 889    yes
# 890     no
# Name: Survived, Length: 891, dtype: object

# %%
from sklearn.model_selection import train_test_split


x_train, x_test, y_train, y_test =train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
x_train.shape

print(f"Total potential features :{x_train.shape[1]}")
print(f"Total sample data :{x_train.shape[0]}")
# Out:
# Total potential features :8
# Total sample data :712

# %%
x_test.shape

print(f"Total potential features :{x_test.shape[1]}")
print(f"Total sample data :{x_test.shape[0]}")
# Out:
# Total potential features :8
# Total sample data :179

# %%
y_train.shape

print(f"Total sample data :{y_train.shape[0]}")
# Out:
# Total sample data :712

# %%
y_test.shape

print(f"Total sample data :{y_test.shape[0]}")
# Out:
# Total sample data :179

# %% [markdown]
# Question 10
#
# Handle missing values in the Titanic dataset by:
#
# Imputing missing Age values using SimpleImputer with mean strategy
#
# Imputing missing Embarked values using most frequent strategy
#
# Imputing missing Cabin values using constant strategy with "Missing"
#
# Finally, check whether any missing values remain.

# %%
x_train.isnull().sum()
# Out:
# Pclass        0
# Sex           0
# Age         140
# SibSp         0
# Parch         0
# Fare          0
# Cabin       553
# Embarked      2
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

age_imputer = SimpleImputer(missing_values=np.nan , strategy= 'mean')
age_imputer.fit(x_train[['Age']])

x_train['Age']= age_imputer.transform(x_train[['Age']])

x_train.isnull().sum()

x_test['Age']= age_imputer.transform(x_test[['Age']])
x_test.isnull().sum()
# Out:
# Pclass        0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Fare          0
# Cabin       134
# Embarked      0
# dtype: int64

# %%
embarked_imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
embarked_imputer.fit(x_train[['Embarked']])

x_train['Embarked'] = embarked_imputer.transform(x_train[['Embarked']]).ravel()
x_train.isnull().sum()

x_test['Embarked']=embarked_imputer.transform(x_test[['Embarked']]).ravel()
x_test.isnull().sum()
# Out:
# Pclass        0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Fare          0
# Cabin       134
# Embarked      0
# dtype: int64

# %%
cabin_imputer = SimpleImputer(missing_values=np.nan , strategy='constant',fill_value='Missing',add_indicator=True)

cabin_imputer.fit(x_train[['Cabin']])

x_train[['Cabin','cabin_missing_indicator']]= cabin_imputer.transform(x_train[['Cabin']])
x_test[['Cabin','cabin_missing_indicator']] = cabin_imputer.transform(x_test[['Cabin']])

# %%
x_train.isnull().sum()
# Out:
# Pclass                     0
# Sex                        0
# Age                        0
# SibSp                      0
# Parch                      0
# Fare                       0
# Cabin                      0
# Embarked                   0
# cabin_missing_indicator    0
# dtype: int64

# %%
x_test.isnull().sum()
# Out:
# Pclass                     0
# Sex                        0
# Age                        0
# SibSp                      0
# Parch                      0
# Fare                       0
# Cabin                      0
# Embarked                   0
# cabin_missing_indicator    0
# dtype: int64
