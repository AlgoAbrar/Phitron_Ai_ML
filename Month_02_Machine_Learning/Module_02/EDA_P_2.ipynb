# %% [markdown]
# # EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('titanic_data_updated.csv')

df
# Out:
#      PassengerId Survived  Pclass  \
# 0              1       no   third
# 1              2      yes   first
# 2              3      yes   third
# 3              4      yes   first
# 4              5       no   third
# ..           ...      ...     ...
# 886          887       no  second
# 887          888      yes   first
# 888          889       no   third
# 889          890      yes   first
# 890          891       no   third
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape

print(f"Total potential features :{df.shape[1]}")
print(f"Total sample data :{df.shape[0]}")
# Out:
# Total potential features :12
# Total sample data :891

# %%
df.sample(10)
# Out:
#      PassengerId Survived  Pclass  \
# 730          731      yes   first
# 492          493       no   first
# 580          581      yes  second
# 85            86      yes   third
# 476          477       no  second
# 69            70       no   third
# 391          392      yes   third
# 673          674      yes  second
# 32            33      yes   third
# 230          231      yes   first
#
#                                                   Name     Sex   Age  SibSp  \
# 730                      Allen, Miss. Elisabeth Walton  female  29.0      0
# 492                         Molson, Mr. Harry Markland    male  55.0      0
# 580                        Christy, Miss. Julie Rachel  female  25.0      1
# 85   Backstrom, Mrs. Karl Alfred (Maria Mathilda Gu...  female  33.0      3
# 476                            Renouf, Mr. Peter Henry    male  34.0      1
# 69                                   Kink, Mr. Vincenz    male  26.0      2
# ...

# %% [markdown]
# ## Multivariate Analysis

# %%
## Working with multiple variables
sns.countplot(x=df['Sex'], hue=df['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
gender_split= df.groupby('Sex')['Survived'].value_counts(normalize=True)

print(gender_split)
# Out:
# Sex     Survived
# female  yes         0.742038
#         no          0.257962
# male    no          0.811092
#         yes         0.188908
# Name: proportion, dtype: float64

# %%
sns.countplot(x=df['Pclass'], hue=df['Survived'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
pclass_split= df.groupby('Pclass')['Survived'].value_counts(normalize=True)

print(pclass_split)
# Out:
# Pclass  Survived
# first   yes         0.629630
#         no          0.370370
# second  no          0.527174
#         yes         0.472826
# third   no          0.757637
#         yes         0.242363
# Name: proportion, dtype: float64

# %%
# barplot categorial vs numerical
sns.barplot(x=df['Pclass'], y=df['Fare'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.barplot(x=df['Survived'], y=df['Age'])
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %% [markdown]
# ## Density Graph

# %%
# Overall distribuiton, outliers detection etc. done by Density Graph

# Distribution of numerical features
# Distribution comparison through KDE Plot

# %% [markdown]
# ## KDE Plot

# %%
# keep numerical value in X axis and categorical value in Y axis
# Probability distribution in Y axis

sns.kdeplot(data=df, x='Age', hue='Survived', fill=True)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## Data Profiling
