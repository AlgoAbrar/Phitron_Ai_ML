# %% [markdown]
# # Question 1

# %%
numbers = list(map(int, input().split()))
a = list(filter(lambda x: x % 3 == 0 and x % 5 != 0, numbers ))

print(a)
# Out:
# [3]

# %% [markdown]
# # Question 2

# %%
def mathfu(a, b):
    try:
        res = ((a*a)+(b*b))/(a-b)
        return res
    except Exception as e:
        return (f"Error: {e}. Division is not possible")

inp= input()
numbers = inp.split()
print(mathfu(a=int(numbers[0]),b=int(numbers[1])))
# Out:
# 17.0

# %% [markdown]
# # Question 3

# %%
with open("./sample_data/data.txt", 'r') as file:
    content=file.read()
    content=content.lower()
    #print(content)
    words= content.split()
    #print(words)
    freq={}
    
    for word in words:
        if word in freq:
            freq[word] += 1
        else:
            freq[word] = 1

    maxc = 0
    theword = ""

    for word in freq:
        if freq[word] > maxc:
            maxc = freq[word]
            theword = word
    #print(maxc)
    print(theword)
# Out:
# python

# %% [markdown]
# # Question 4

# %%
# Solve Question 4

stringg= input()
worrd= stringg.split()
#print(worrd)

characters= list(len(word) for word in worrd)
print(characters)
# Out:
# [7, 8, 2, 3]

# %% [markdown]
# # Question 5

# %%
# Solve Question 5

n=int(input())
#print(type(n))
temp=n
reversee=0

while n!=0:
  dig=n%10
  reversee= (reversee*10)+dig
  n//=10

#print(type(reversee))
if reversee==temp:
  print("Mirror Number")
else:
  print("Not Mirror")
# Out:
# Mirror Number
